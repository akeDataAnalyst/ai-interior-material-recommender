# %% [markdown]
# #### 1. Load enriched data & model

# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("../data")

ENRICHED_FILE = DATA_DIR / "interior_materials_enriched_20260219_1714.parquet" 

df = pd.read_parquet(ENRICHED_FILE)
print(f"Loaded {len(df)} rows with embeddings")
print("Columns:", df.columns.tolist())
display(df.head(3))
# Out:
# Loaded 299 rows with embeddings
# Columns: ['material_name', 'price_etb', 'price_text', 'unit', 'last_checked', 'detail_url', 'category', 'source', 'scraped_at', 'unit_norm', 'keywords', 'text_for_embedding', 'embedding']
#              material_name  price_etb         price_text unit  last_checked  \
# 0  Clear Glass - 3mm thick     1202.0  1,202.00 Brper m2   m2  May 29, 2024
# 1  Clear Glass - 4mm thick     1537.0  1,537.00 Brper m2   m2  May 29, 2024
# 2  Clear Glass - 5mm thick     1767.0  1,767.00 Brper m2   m2  May 29, 2024
#
#    detail_url   category        source          scraped_at     unit_norm  \
# 0         NaN  Finishing  2merkato.com 2026-02-19 16:44:00  square meter
# 1         NaN  Finishing  2merkato.com 2026-02-19 16:44:00  square meter
# 2         NaN  Finishing  2merkato.com 2026-02-19 16:44:00  square meter
#
#                                keywords  \
# 0  [clear, color:clear, size/thickness]
# 1  [clear, color:clear, size/thickness]
# 2  [clear, color:clear, size/thickness]
#
#                                   text_for_embedding  \
# 0  Clear Glass - 3mm thick Finishing square meter...
# 1  Clear Glass - 4mm thick Finishing square meter...
# 2  Clear Glass - 5mm thick Finishing square meter...
#
#                                            embedding
# 0  [0.079825744, 0.03837128, -0.014964104, -0.011...
# 1  [0.09515599, 0.03919774, -0.01531778, -0.00241...
# 2  [0.08462944, 0.03924823, -0.015149601, 0.00537...

# %% [markdown]
# #### 2. Recommender function

# %%
import torch  
import torch._prims 

from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Load model
model = SentenceTransformer("all-MiniLM-L6-v2")
print("Model loaded successfully.")

def recommend_materials(
    query_text: str,
    df: pd.DataFrame,
    top_k: int = 5,
    min_similarity: float = 0.4 
):
    if not query_text.strip():
        return pd.DataFrame()

    query_emb = model.encode([query_text], normalize_embeddings=True)[0]
    embeddings_array = np.stack(df["embedding"].values)
    similarities = cosine_similarity([query_emb], embeddings_array)[0]

    result_df = df.copy()
    result_df["similarity"] = similarities.round(3)

    result_df = result_df[result_df["similarity"] >= min_similarity]
    result_df = result_df.sort_values("similarity", ascending=False).head(top_k)

    cols = ["material_name", "category", "price_etb", "unit_norm", "similarity"]
    if "detail_url" in result_df.columns:
        cols.append("detail_url")

    return result_df[cols]
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded successfully.

# %% [markdown]
# #### 3. Test the Recommender

# %%
test_queries = [
    "modern blue tiles under 2000 ETB",
    "white marble for kitchen counter",
    "frosted glass partition",
    "red paint for bedroom wall",
    "cheap sanitary ware for bathroom",
    "galvanized metal sheet for ceiling",
    "clear glass 5mm thick",
    "electrical switch for home"
]

print("Testing recommender with lowered threshold (0.4)\n")

for q in test_queries:
    print(f"\n{'='*60}")
    print(f"Query: {q}")
    print(f"{'-'*60}")
    
    results = recommend_materials(
        query_text=q,
        df=df,
        top_k=8,
        min_similarity=0.4
    )
    
    if results.empty:
        print("  No matches found above 0.4 similarity.")
        print("  → Suggestions: Try a more general query or lower min_similarity to 0.35")
    else:
        display_df = results.copy()
        display_df["price_etb"] = display_df["price_etb"].apply(lambda x: f"{x:,.0f} ETB" if pd.notna(x) else "N/A")
        display_df["similarity"] = display_df["similarity"].round(3)
        
        display(display_df[["material_name", "category", "price_etb", "unit_norm", "similarity", "detail_url"]])
        
        print(f"  Top match: {display_df.iloc[0]['material_name']} (score: {display_df.iloc[0]['similarity']})")
        print(f"  Total matches: {len(display_df)}")
# Out:
# Testing recommender with lowered threshold (0.4)
#
#
# ============================================================
# Query: modern blue tiles under 2000 ETB
# ------------------------------------------------------------
#                                         material_name          category  \
# 26                          Classic 2000+ Tint colors          Sanitary
# 157                            PVC Y: φ50 double ring  Tiles & Ceramics
# 158                  PVC reducer: 110-50  double ring  Tiles & Ceramics
# 15       Reflective Glass - 5mm thick ocean blue ref.         Finishing
# 187                                            Teflon  Tiles & Ceramics
# 159                           PVC T: φ110 double ring  Tiles & Ceramics
# 138  Water Closet: high level flashing (Turkish type)  Tiles & Ceramics
# 149                  Water tanker: 2000lt fiber glass  Tiles & Ceramics
#
#       price_etb     unit_norm  similarity  detail_url
# 26      642 ETB       unknown       0.458         NaN
# 157     408 ETB         piece       0.454         NaN
# 158     408 ETB         piece       0.450         NaN
# 15    1,967 ETB  square meter       0.436         NaN
# 187      90 ETB         piece       0.435         NaN
# 159     942 ETB         piece       0.434         NaN
# 138   4,500 ETB         piece       0.433         NaN
# 149  12,200 ETB         piece       0.432         NaN
#   Top match: Classic 2000+ Tint colors (score: 0.4580000042915344)
#   Total matches: 8
#
# ============================================================
# Query: white marble for kitchen counter
# ------------------------------------------------------------
#                                      material_name          category  \
# 36              Texture Paint (Quartz) Super White          Sanitary
# 27             Ecosilk Artique Special Pearl paint          Sanitary
# 22                Quartz Paint 200 (16lit or 25kg)          Sanitary
# 144  Kitchen sink: double bowel, 50 x 120 (Milano)  Tiles & Ceramics
# 136        Water Closet: low flash (Tabor Ceramic)  Tiles & Ceramics
# 143    Kitchen sink: double bowel, 50 x 120 (Aqua)  Tiles & Ceramics
#
#       price_etb unit_norm  similarity  detail_url
# 36      109 ETB   unknown       0.519         NaN
# 27      882 ETB  kilogram       0.470         NaN
# 22    1,550 ETB   unknown       0.451         NaN
# 144   5,500 ETB     piece       0.406         NaN
# 136  26,185 ETB     piece       0.404         NaN
# 143   3,700 ETB     piece       0.400         NaN
#   Top match: Texture Paint (Quartz) Super White (score: 0.5189999938011169)
#   Total matches: 6
#
# ============================================================
# Query: frosted glass partition
# ------------------------------------------------------------
#                 material_name   category  price_etb     unit_norm  similarity  \
# 11  Frosted Glass - 6mm thick  Finishing  2,254 ETB  square meter       0.562
# 8   Frosted Glass - 3mm thick  Finishing  1,967 ETB  square meter       0.557
# 9   Frosted Glass - 4mm thick  Finishing  1,120 ETB  square meter       0.557
# 10  Frosted Glass - 5mm thick  Finishing  2,063 ETB  square meter       0.539
#
#     detail_url
# 11         NaN
# 8          NaN
# 9          NaN
# 10         NaN
#   Top match: Frosted Glass - 6mm thick (score: 0.5619999766349792)
#   Total matches: 4
#
# ============================================================
# Query: red paint for bedroom wall
# ------------------------------------------------------------
#                 material_name  category price_etb unit_norm  similarity  \
# 60     Epoxy Wall Paint (3KG)  Sanitary   800 ETB  kilogram       0.474
# 61  Epoxy Wall Paint Hardener  Sanitary   850 ETB  kilogram       0.410
#
#     detail_url
# 60         NaN
# 61         NaN
#   Top match: Epoxy Wall Paint (3KG) (score: 0.4740000069141388)
#   Total matches: 2
#
# ============================================================
# Query: cheap sanitary ware for bathroom
# ------------------------------------------------------------
#                                      material_name          category  \
# 144  Kitchen sink: double bowel, 50 x 120 (Milano)  Tiles & Ceramics
# 142           Kitchen sink: single bowel, 50 x 120  Tiles & Ceramics
# 143    Kitchen sink: double bowel, 50 x 120 (Aqua)  Tiles & Ceramics
# 38                         Budget Synthetic Enamel          Sanitary
# 24                           Budget Emulsion paint          Sanitary
# 31                     Premium Acyrylic Wall Putty          Sanitary
# 26                       Classic 2000+ Tint colors          Sanitary
# 21                                   Plastic Paint          Sanitary
#
#      price_etb unit_norm  similarity  detail_url
# 144  5,500 ETB     piece       0.486         NaN
# 142  6,000 ETB     piece       0.483         NaN
# 143  3,700 ETB     piece       0.482         NaN
# 38     295 ETB  kilogram       0.476         NaN
# 24      93 ETB   unknown       0.471         NaN
# 31      97 ETB   unknown       0.463         NaN
# 26     642 ETB   unknown       0.458         NaN
# 21     300 ETB   unknown       0.449         NaN
#   Top match: Kitchen sink: double bowel, 50 x 120 (Milano) (score: 0.4860000014305115)
#   Total matches: 8
#
# ============================================================
# Query: galvanized metal sheet for ceiling
# ------------------------------------------------------------
#                                          material_name           category  \
# 239       G32 Corrugated Galvanized Iron Sheet - KOSPI  Roofing & Ceiling
# 238       G32 Corrugated Galvanized Iron Sheet - Akaki  Roofing & Ceiling
# 236       G28 Corrugated Galvanized Iron Sheet - KOSPI  Roofing & Ceiling
# 237       G30 Corrugated Galvanized Iron Sheet - Akaki  Roofing & Ceiling
# 235       G28 Corrugated Galvanized Iron Sheet - Akaki  Roofing & Ceiling
# 294  Metal Flashing-Galvanized Sheet G-28 for Gutte...  Roofing & Ceiling
# 241       G35 Corrugated Galvanized Iron Sheet - KOSPI  Roofing & Ceiling
# 240       G35 Corrugated Galvanized Iron Sheet - Akaki  Roofing & Ceiling
#
#      price_etb unit_norm  similarity  detail_url
# 239  1,100 ETB     piece       0.685         NaN
# 238  1,185 ETB     piece       0.682         NaN
# 236  1,250 ETB     piece       0.673         NaN
# 237  1,275 ETB     piece       0.666         NaN
# 235  1,335 ETB     piece       0.658         NaN
# 294    996 ETB     piece       0.654         NaN
# 241    900 ETB     piece       0.653         NaN
# 240  1,000 ETB     piece       0.643         NaN
#   Top match: G32 Corrugated Galvanized Iron Sheet - KOSPI (score: 0.6850000023841858)
#   Total matches: 8
#
# ============================================================
# Query: clear glass 5mm thick
# ------------------------------------------------------------
#                    material_name   category  price_etb     unit_norm  \
# 2        Clear Glass - 5mm thick  Finishing  1,767 ETB  square meter
# 1        Clear Glass - 4mm thick  Finishing  1,537 ETB  square meter
# 3        Clear Glass - 6mm thick  Finishing  2,495 ETB  square meter
# 0        Clear Glass - 3mm thick  Finishing  1,202 ETB  square meter
# 18      Tinted Glass - 5mm thick  Finishing  1,680 ETB  square meter
# 19      Tinted Glass - 6mm thick  Finishing  2,349 ETB  square meter
# 17      Tinted Glass - 4mm thick  Finishing  1,490 ETB  square meter
# 6   Clear and Colored Glass: 6mm  Finishing  1,350 ETB  square meter
#
#     similarity  detail_url
# 2        0.739         NaN
# 1        0.719         NaN
# 3        0.714         NaN
# 0        0.704         NaN
# 18       0.700         NaN
# 19       0.683         NaN
# 17       0.666         NaN
# 6        0.665         NaN
#   Top match: Clear Glass - 5mm thick (score: 0.7390000224113464)
#   Total matches: 8
#
# ============================================================
# Query: electrical switch for home
# ------------------------------------------------------------
#               material_name    category price_etb unit_norm  similarity  \
# 81            Single switch  Electrical   540 ETB     piece       0.520
# 83  Single switch with bell  Electrical   650 ETB     piece       0.490
# 82            Double switch  Electrical   400 ETB     piece       0.473
# 84  Double switch with bell  Electrical   425 ETB     piece       0.431
#
#     detail_url
# 81         NaN
# 83         NaN
# 82         NaN
# 84         NaN
#   Top match: Single switch (score: 0.5199999809265137)
#   Total matches: 4
